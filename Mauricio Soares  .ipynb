# %% [markdown]
# #   Import Library
#     import library hodi inisializa funsaun sira nebe ita atu uza

# %%
import pandas as pd                       #import pandas package  
import matplotlib.pyplot as plt         # import matplotlib ka  grafiku ba python

# %%
Iris=pd.read_csv('iris.csv')

Iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %% [markdown]
# # 1.  Dimension

# %%
Iris.shape # hodi hatene quantidade husi lina no koluna nebe iha
# Out:
# (150, 5)

# %% [markdown]
# # 2. Central Tendency
#
# kontta valor husi (count,mean,stdandard deviation,min,max no valor husi cada percentagem)

# %%
Iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # 3. Info

# %%
Iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %% [markdown]
# # 4.Check null values
# hodi hare karik

# %%
 Iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# # 5. Data Dispersion

# %% [markdown]
# Correlation

# %%
Iris.corr() # ida ne'e hodi fo sai ka kalkula valor correlation
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %% [markdown]
# Range
# tuir mai, sei kalkula valor range ba kada features

# %%
print (Iris['sepal_length'].max() - Iris['sepal_length'].min())
# Out:
# 3.6000000000000005

# %%
print (Iris['sepal_width'].max() - Iris['sepal_width'].min())
# Out:
# 2.4000000000000004

# %%
print (Iris['petal_length'].max() - Iris['petal_length'].min())
# Out:
# 5.9

# %%
print (Iris['petal_width'].max() - Iris['petal_width'].min())
# Out:
# 2.4

# %% [markdown]
# # 6. Visualizing (using matplotlib)
#         iha parte vizulizasaun nian, atu hodi simplifika ka klarifika liu tan dadus nebe ita analiza ne'e
#         ho modelu grafiku.

# %%
plt.hist(Iris.corr())


plt.show()

# %%
plt.contour(Iris.corr())

plt.show()

# %%
plt.pcolor(Iris.corr())


plt.show()
